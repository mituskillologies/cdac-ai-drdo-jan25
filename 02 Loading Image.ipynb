# %% [markdown]
# ##### Install the libraries

# %%
pip install opencv-python pillow scikit-image
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in ./.local/lib/python3.10/site-packages (4.10.0.84)
# Requirement already satisfied: pillow in ./.local/lib/python3.10/site-packages (11.0.0)
# Requirement already satisfied: scikit-image in ./.local/lib/python3.10/site-packages (0.24.0)
# Requirement already satisfied: numpy>=1.21.2 in ./.local/lib/python3.10/site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.11.4)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (3.2.1)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2023.12.9)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (23.2)
# Requirement already satisfied: lazy-loader>=0.4 in ./.local/lib/python3.10/site-packages (from scikit-image) (0.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##### Using OpenCV

# %%
import cv2

# %%
# Download the images from : https://mitu.co.in/dataset
# Store in current working directory

# %%
import os
os.getcwd()
# Out:
# '/home/mitu/cdac-drdo-jan25'

# %%
img_cv = cv2.imread('images/sachin.jpg')

# %%
cv2.imshow('My Image', img_cv)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Use matplotlib

# %%
import matplotlib.pyplot as plt

# %%
img_plt = plt.imread('images/sachin.jpg')

# %%
plt.imshow(img_plt)

# %% [markdown]
# ##### Using scikit-image

# %%
from skimage import io

# %%
img_ski = io.imread('images/sachin.jpg')

# %%
io.imshow(img_ski)

# %% [markdown]
# ##### Using the pillow library

# %%
from PIL import Image

# %%
img_pil = Image.open('images/sachin.jpg')

# %%
img_pil.show()

# %%
img_pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=850x1075>

# %%
import tensorflow as tf

# %%
img_tf = tf.io.read_file('images/sachin.jpg')
img_tf = tf.image.decode_image(img_tf)

# %%
tf.io.
plt.imshow(img_tf)

# %%
img_cv
# Out:
# array([[[ 26,  19,  16],
#         [ 26,  19,  16],
#         [ 26,  19,  16],
#         ...,
#         [ 33,  26,  23],
#         [ 31,  28,  24],
#         [ 31,  28,  24]],
#
#        [[ 26,  19,  16],
#         [ 26,  19,  16],
#         [ 26,  19,  16],
#         ...,
#         [ 33,  26,  23],
#         [ 29,  26,  22],
#         [ 29,  26,  22]],
#
#        [[ 26,  19,  16],
#         [ 26,  19,  16],
#         [ 26,  19,  16],
#         ...,
#         [ 33,  26,  23],
#         [ 31,  24,  21],
#         [ 31,  24,  21]],
#
#        ...,
#
#        [[131, 188, 197],
#         [132, 189, 198],
#         [131, 190, 199],
#         ...,
#         [103, 140, 138],
#         [102, 137, 133],
#         [104, 137, 133]],
#
#        [[132, 189, 198],
#         [133, 190, 199],
#         [132, 191, 200],
#         ...,
#         [101, 138, 136],
#         [102, 136, 136],
#         [104, 135, 136]],
#
#        [[133, 190, 199],
#         [134, 191, 200],
#         [133, 192, 201],
#         ...,
#         [100, 136, 136],
#         [102, 135, 138],
#         [104, 134, 139]]], dtype=uint8)

# %%
img_plt
# Out:
# array([[[ 16,  19,  26],
#         [ 16,  19,  26],
#         [ 16,  19,  26],
#         ...,
#         [ 23,  26,  33],
#         [ 24,  28,  31],
#         [ 24,  28,  31]],
#
#        [[ 16,  19,  26],
#         [ 16,  19,  26],
#         [ 16,  19,  26],
#         ...,
#         [ 23,  26,  33],
#         [ 22,  26,  29],
#         [ 22,  26,  29]],
#
#        [[ 16,  19,  26],
#         [ 16,  19,  26],
#         [ 16,  19,  26],
#         ...,
#         [ 23,  26,  33],
#         [ 21,  24,  31],
#         [ 21,  24,  31]],
#
#        ...,
#
#        [[197, 188, 131],
#         [198, 189, 132],
#         [199, 190, 131],
#         ...,
#         [138, 140, 103],
#         [133, 137, 102],
#         [133, 137, 104]],
#
#        [[198, 189, 132],
#         [199, 190, 133],
#         [200, 191, 132],
#         ...,
#         [136, 138, 101],
#         [136, 136, 102],
#         [136, 135, 104]],
#
#        [[199, 190, 133],
#         [200, 191, 134],
#         [201, 192, 133],
#         ...,
#         [136, 136, 100],
#         [138, 135, 102],
#         [139, 134, 104]]], dtype=uint8)

# %%
img_tf
# Out:
# <tf.Tensor: shape=(1075, 850, 3), dtype=uint8, numpy=
# array([[[ 14,  19,  23],
#         [ 14,  19,  23],
#         [ 14,  19,  23],
#         ...,
#         [ 22,  27,  31],
#         [ 22,  28,  28],
#         [ 22,  28,  28]],
#
#        [[ 15,  20,  24],
#         [ 15,  20,  24],
#         [ 15,  20,  24],
#         ...,
#         [ 21,  26,  30],
#         [ 21,  26,  29],
#         [ 21,  26,  29]],
#
#        [[ 15,  20,  24],
#         [ 15,  20,  24],
#         [ 15,  20,  24],
#         ...,
#         [ 21,  26,  30],
#         [ 20,  25,  29],
#         [ 20,  25,  29]],
#
#        ...,
#
#        [[194, 188, 128],
#         [196, 190, 130],
#         [199, 190, 131],
#         ...,
#         [138, 140, 101],
#         [131, 137,  99],
#         [131, 137, 101]],
#
#        [[195, 189, 129],
#         [196, 190, 130],
#         [200, 191, 132],
#         ...,
#         [136, 138,  99],
#         [134, 136,  99],
#         [134, 135, 101]],
#
#        [[196, 190, 130],
#         [198, 192, 132],
#         [201, 192, 133],
#         ...,
#         [136, 136,  98],
#         [135, 135,  99],
#         [137, 134, 101]]], dtype=uint8)>

# %%
img_ski
# Out:
# array([[[ 16,  19,  26],
#         [ 16,  19,  26],
#         [ 16,  19,  26],
#         ...,
#         [ 23,  26,  33],
#         [ 24,  28,  31],
#         [ 24,  28,  31]],
#
#        [[ 16,  19,  26],
#         [ 16,  19,  26],
#         [ 16,  19,  26],
#         ...,
#         [ 23,  26,  33],
#         [ 22,  26,  29],
#         [ 22,  26,  29]],
#
#        [[ 16,  19,  26],
#         [ 16,  19,  26],
#         [ 16,  19,  26],
#         ...,
#         [ 23,  26,  33],
#         [ 21,  24,  31],
#         [ 21,  24,  31]],
#
#        ...,
#
#        [[197, 188, 131],
#         [198, 189, 132],
#         [199, 190, 131],
#         ...,
#         [138, 140, 103],
#         [133, 137, 102],
#         [133, 137, 104]],
#
#        [[198, 189, 132],
#         [199, 190, 133],
#         [200, 191, 132],
#         ...,
#         [136, 138, 101],
#         [136, 136, 102],
#         [136, 135, 104]],
#
#        [[199, 190, 133],
#         [200, 191, 134],
#         [201, 192, 133],
#         ...,
#         [136, 136, 100],
#         [138, 135, 102],
#         [139, 134, 104]]], dtype=uint8)

# %%
img_cv.shape
# Out:
# (1075, 850, 3)

# %%
type(img_cv)
# Out:
# numpy.ndarray

# %%
type(img_plt)
# Out:
# numpy.ndarray

# %%
type(img_pil)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img_cv[500,400]
# Out:
# array([33, 25, 25], dtype=uint8)

# %%
cdac = plt.imread('images/CDAC_LOGO.png')

# %%
plt.imshow(cdac)

# %%
cdac.shape
# Out:
# (956, 1838, 4)
