# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(1,10,0.25)

# %%
x
# Out:
# array([1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 ,
#        3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25, 5.5 , 5.75, 6.  , 6.25,
#        6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  , 8.25, 8.5 , 8.75, 9.  ,
#        9.25, 9.5 , 9.75])

# %%
y = x ** 2 *5.22 + 16.37

# %%
y
# Out:
# array([ 21.59   ,  24.52625,  28.115  ,  32.35625,  37.25   ,  42.79625,
#         48.995  ,  55.84625,  63.35   ,  71.50625,  80.315  ,  89.77625,
#         99.89   , 110.65625, 122.075  , 134.14625, 146.87   , 160.24625,
#        174.275  , 188.95625, 204.29   , 220.27625, 236.915  , 254.20625,
#        272.15   , 290.74625, 309.995  , 329.89625, 350.45   , 371.65625,
#        393.515  , 416.02625, 439.19   , 463.00625, 487.475  , 512.59625])

# %%
plt.plot(x, y)

# %%
y = x ** 4 *5.22 + 16.37 
plt.plot(x, y)
