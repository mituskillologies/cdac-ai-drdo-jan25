# %% [markdown]
# ##### Import the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ##### Linear Regression

# %%
df = pd.read_csv('datasets/Salary_Data.csv')
x = df[['YearsExperience']]
y = df['Salary']

from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x,y)
print('Accuracy:', reg.score(x, y))
# Out:
# Accuracy: 0.9569566641435086

# %% [markdown]
# ##### Polynomial Transformation

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2)

# %%
x_poly = poly.fit_transform(x)

# %%
x_poly
# Out:
# array([[  1.  ,   1.1 ,   1.21],
#        [  1.  ,   1.3 ,   1.69],
#        [  1.  ,   1.5 ,   2.25],
#        [  1.  ,   2.  ,   4.  ],
#        [  1.  ,   2.2 ,   4.84],
#        [  1.  ,   2.9 ,   8.41],
#        [  1.  ,   3.  ,   9.  ],
#        [  1.  ,   3.2 ,  10.24],
#        [  1.  ,   3.2 ,  10.24],
#        [  1.  ,   3.7 ,  13.69],
#        [  1.  ,   3.9 ,  15.21],
#        [  1.  ,   4.  ,  16.  ],
#        [  1.  ,   4.  ,  16.  ],
#        [  1.  ,   4.1 ,  16.81],
#        [  1.  ,   4.5 ,  20.25],
#        [  1.  ,   4.9 ,  24.01],
#        [  1.  ,   5.1 ,  26.01],
#        [  1.  ,   5.3 ,  28.09],
#        [  1.  ,   5.9 ,  34.81],
#        [  1.  ,   6.  ,  36.  ],
#        [  1.  ,   6.8 ,  46.24],
#        [  1.  ,   7.1 ,  50.41],
#        [  1.  ,   7.9 ,  62.41],
#        [  1.  ,   8.2 ,  67.24],
#        [  1.  ,   8.7 ,  75.69],
#        [  1.  ,   9.  ,  81.  ],
#        [  1.  ,   9.5 ,  90.25],
#        [  1.  ,   9.6 ,  92.16],
#        [  1.  ,  10.3 , 106.09],
#        [  1.  ,  10.5 , 110.25]])

# %%
reg = LinearRegression()
reg.fit(x_poly,y)
print('Accuracy:', reg.score(x_poly, y))
# Out:
# Accuracy: 0.956975168321065

# %%
poly = PolynomialFeatures(degree=4)
x_poly = poly.fit_transform(x)

reg = LinearRegression()
reg.fit(x_poly,y)
print('Accuracy:', reg.score(x_poly, y))
# Out:
# Accuracy: 0.9636560599375091

# %%
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.grid()
plt.scatter(x, y, color = 'g')
plt.plot(x, reg.predict(x_poly), color = 'r')

# %%
acc = []
for i in range(1,21):
    poly = PolynomialFeatures(degree=i)
    x_poly = poly.fit_transform(x)
    
    reg = LinearRegression()
    reg.fit(x_poly,y)
    acc.append(reg.score(x_poly, y))

# %%
acc
# Out:
# [0.9569566641435086,
#  0.956975168321065,
#  0.9635969766249464,
#  0.9636560599375091,
#  0.9665546834956744,
#  0.96736935771699,
#  0.972257892102649,
#  0.9728154307144777,
#  0.9732969097554259,
#  0.9809837412679417,
#  0.9821746338521761,
#  0.9830101778689884,
#  0.9830302172893944,
#  0.981968893157383,
#  0.9804880488084265,
#  0.9792411412768544,
#  0.9800324937279813,
#  0.9655365804456496,
#  0.9585869083280407,
#  0.953946912318687]

# %%
plt.figure(figsize=(16,9))
plt.xlabel('Degree')
plt.ylabel('Acuracy')
plt.ylim(0.9, 1)
plt.bar(range(1,21), acc, color = 'g')
# Out:
# <BarContainer object of 20 artists>

# %%
poly = PolynomialFeatures(degree=13)
x_poly = poly.fit_transform(x)

reg = LinearRegression()
reg.fit(x_poly,y)
print('Accuracy:', reg.score(x_poly, y))
# Out:
# Accuracy: 0.9830302172893944

# %%
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.grid()
plt.scatter(x, y, color = 'g')
plt.plot(x, reg.predict(x_poly), color = 'r')
