# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(1,10,0.25)

# %%
x
# Out:
# array([1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 ,
#        3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25, 5.5 , 5.75, 6.  , 6.25,
#        6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  , 8.25, 8.5 , 8.75, 9.  ,
#        9.25, 9.5 , 9.75])

# %%
y = 0.67 * x + 12.405

# %%
y
# Out:
# array([13.075 , 13.2425, 13.41  , 13.5775, 13.745 , 13.9125, 14.08  ,
#        14.2475, 14.415 , 14.5825, 14.75  , 14.9175, 15.085 , 15.2525,
#        15.42  , 15.5875, 15.755 , 15.9225, 16.09  , 16.2575, 16.425 ,
#        16.5925, 16.76  , 16.9275, 17.095 , 17.2625, 17.43  , 17.5975,
#        17.765 , 17.9325, 18.1   , 18.2675, 18.435 , 18.6025, 18.77  ,
#        18.9375])

# %%
plt.plot(x, y)

# %%
plt.scatter(x, y)
