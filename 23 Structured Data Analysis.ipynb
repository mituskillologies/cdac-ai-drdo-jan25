# %% [markdown]
# ##### Dataset

# %%
# Link: https://mitu.co.in/dataset
# Download all the files with name student.... and store in datasets

# %%
import pandas as pd

# %% [markdown]
# ##### Import the data

# %%
df = pd.read_csv('datasets/student.csv')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = pd.read_csv('datasets/student1.csv')

# %%
df1
# Out:
#     1     anil  TE  56.77  22
# 0   2     amit  TE  59.77  21
# 1   3   aniket  BE  76.88  19
# 2   4  ajinkya  TE  69.66  20
# 3   5     asha  TE  63.28  20
# 4   6   ayesha  BE  49.55  20
# 5   7     amar  BE  65.34  19
# 6   8    amita  BE  68.33  23
# 7   9     amol  TE  56.75  20
# 8  10    anmol  BE  78.66  21

# %%
df1 = pd.read_csv('datasets/student1.csv', names=['A','B','C','D','E'])

# %%
df1
# Out:
#     A        B   C      D   E
# 0   1     anil  TE  56.77  22
# 1   2     amit  TE  59.77  21
# 2   3   aniket  BE  76.88  19
# 3   4  ajinkya  TE  69.66  20
# 4   5     asha  TE  63.28  20
# 5   6   ayesha  BE  49.55  20
# 6   7     amar  BE  65.34  19
# 7   8    amita  BE  68.33  23
# 8   9     amol  TE  56.75  20
# 9  10    anmol  BE  78.66  21

# %%
df1 = pd.read_csv('datasets/student1.csv', header=None)

# %%
df1
# Out:
#     0        1   2      3   4
# 0   1     anil  TE  56.77  22
# 1   2     amit  TE  59.77  21
# 2   3   aniket  BE  76.88  19
# 3   4  ajinkya  TE  69.66  20
# 4   5     asha  TE  63.28  20
# 5   6   ayesha  BE  49.55  20
# 6   7     amar  BE  65.34  19
# 7   8    amita  BE  68.33  23
# 8   9     amol  TE  56.75  20
# 9  10    anmol  BE  78.66  21

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
df2 = pd.read_csv('datasets/student1.csv', nrows=5)

# %%
df2
# Out:
#    1     anil  TE  56.77  22
# 0  2     amit  TE  59.77  21
# 1  3   aniket  BE  76.88  19
# 2  4  ajinkya  TE  69.66  20
# 3  5     asha  TE  63.28  20
# 4  6   ayesha  BE  49.55  20

# %%
df3 = pd.read_csv('datasets/student3.tsv')

# %%
df3
# Out:
#   roll\tname\tclass\tmarks\tage
# 0        1\tanil\tTE\t56.77\t22
# 1        2\tamit\tTE\t59.77\t21
# 2      3\taniket\tBE\t76.88\t19
# 3     4\tajinkya\tTE\t69.66\t20
# 4        5\tasha\tTE\t63.28\t20
# 5      6\tayesha\tBE\t49.55\t20
# 6        7\tamar\tBE\t65.34\t19
# 7       8\tamita\tBE\t68.33\t23
# 8        9\tamol\tTE\t56.75\t20
# 9      10\tanmol\tBE\t78.66\t21

# %%
df3 = pd.read_csv('datasets/student3.tsv', sep = '\t')

# %%
df3
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df4 = pd.read_csv('https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv')

# %%
df4
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ##### Basic Attributes

# %%
df.shape
# Out:
# (10, 5)

# %%
df.size
# Out:
# 50

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
df.ndim
# Out:
# 2

# %%
df.values
# Out:
# array([[1, 'anil', 'TE', 56.77, 22],
#        [2, 'amit', 'TE', 59.77, 21],
#        [3, 'aniket', 'BE', 76.88, 19],
#        [4, 'ajinkya', 'TE', 69.66, 20],
#        [5, 'asha', 'TE', 63.28, 20],
#        [6, 'ayesha', 'BE', 49.55, 20],
#        [7, 'amar', 'BE', 65.34, 19],
#        [8, 'amita', 'BE', 68.33, 23],
#        [9, 'amol', 'TE', 56.75, 20],
#        [10, 'anmol', 'BE', 78.66, 21]], dtype=object)

# %%
df.T
# Out:
#            0      1       2        3      4       5      6      7      8  \
# roll       1      2       3        4      5       6      7      8      9
# name    anil   amit  aniket  ajinkya   asha  ayesha   amar  amita   amol
# class     TE     TE      BE       TE     TE      BE     BE     BE     TE
# marks  56.77  59.77   76.88    69.66  63.28   49.55  65.34  68.33  56.75
# age       22     21      19       20     20      20     19     23     20
#
#            9
# roll      10
# name   anmol
# class     BE
# marks  78.66
# age       21

# %%
df.head()
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df.head(3)
# Out:
#    roll    name class  marks  age
# 0     1    anil    TE  56.77   22
# 1     2    amit    TE  59.77   21
# 2     3  aniket    BE  76.88   19

# %%
df.tail()
# Out:
#    roll    name class  marks  age
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %%
df.tail(2)
# Out:
#    roll   name class  marks  age
# 8     9   amol    TE  56.75   20
# 9    10  anmol    BE  78.66   21

# %% [markdown]
# ##### Slicing - Index Based

# %%
x = df.iloc[2:8,1:4]

# %%
x
# Out:
#       name class  marks
# 2   aniket    BE  76.88
# 3  ajinkya    TE  69.66
# 4     asha    TE  63.28
# 5   ayesha    BE  49.55
# 6     amar    BE  65.34
# 7    amita    BE  68.33

# %%
df.iloc[2:8,:4]
# Out:
#    roll     name class  marks
# 2     3   aniket    BE  76.88
# 3     4  ajinkya    TE  69.66
# 4     5     asha    TE  63.28
# 5     6   ayesha    BE  49.55
# 6     7     amar    BE  65.34
# 7     8    amita    BE  68.33

# %%
df.iloc[:8,:4]
# Out:
#    roll     name class  marks
# 0     1     anil    TE  56.77
# 1     2     amit    TE  59.77
# 2     3   aniket    BE  76.88
# 3     4  ajinkya    TE  69.66
# 4     5     asha    TE  63.28
# 5     6   ayesha    BE  49.55
# 6     7     amar    BE  65.34
# 7     8    amita    BE  68.33

# %%
df.iloc[2:,1:4]
# Out:
#       name class  marks
# 2   aniket    BE  76.88
# 3  ajinkya    TE  69.66
# 4     asha    TE  63.28
# 5   ayesha    BE  49.55
# 6     amar    BE  65.34
# 7    amita    BE  68.33
# 8     amol    TE  56.75
# 9    anmol    BE  78.66

# %%
df.iloc[2:,1:]
# Out:
#       name class  marks  age
# 2   aniket    BE  76.88   19
# 3  ajinkya    TE  69.66   20
# 4     asha    TE  63.28   20
# 5   ayesha    BE  49.55   20
# 6     amar    BE  65.34   19
# 7    amita    BE  68.33   23
# 8     amol    TE  56.75   20
# 9    anmol    BE  78.66   21

# %%
df.iloc[:,:]
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.iloc[[4,6,5,7,2],1:4]
# Out:
#      name class  marks
# 4    asha    TE  63.28
# 6    amar    BE  65.34
# 5  ayesha    BE  49.55
# 7   amita    BE  68.33
# 2  aniket    BE  76.88

# %%
df.iloc[[4,6,5,7,2],[1,4]]
# Out:
#      name  age
# 4    asha   20
# 6    amar   19
# 5  ayesha   20
# 7   amita   23
# 2  aniket   19

# %%
df.iloc[5,1:4]
# Out:
# name     ayesha
# class        BE
# marks     49.55
# Name: 5, dtype: object

# %%
df.iloc[[4,6,5,7,2],1]
# Out:
# 4      asha
# 6      amar
# 5    ayesha
# 7     amita
# 2    aniket
# Name: name, dtype: object

# %%
df.iloc[3,1]
# Out:
# 'ajinkya'

# %%
df.iloc[[4,6,5,7,2],:-2]
# Out:
#    roll    name class
# 4     5    asha    TE
# 6     7    amar    BE
# 5     6  ayesha    BE
# 7     8   amita    BE
# 2     3  aniket    BE

# %%
df.iloc[[4,6,5,7,2],-1]
# Out:
# 4    20
# 6    19
# 5    20
# 7    23
# 2    19
# Name: age, dtype: int64

# %%
df.drop(5)
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.drop([5,1,8])
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21

# %% [markdown]
# ##### Slicing - Label Based

# %%
df.loc[:,'name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.loc[:,['name','marks']]
# Out:
#       name  marks
# 0     anil  56.77
# 1     amit  59.77
# 2   aniket  76.88
# 3  ajinkya  69.66
# 4     asha  63.28
# 5   ayesha  49.55
# 6     amar  65.34
# 7    amita  68.33
# 8     amol  56.75
# 9    anmol  78.66

# %%
df.loc[:,'name':'marks']
# Out:
#       name class  marks
# 0     anil    TE  56.77
# 1     amit    TE  59.77
# 2   aniket    BE  76.88
# 3  ajinkya    TE  69.66
# 4     asha    TE  63.28
# 5   ayesha    BE  49.55
# 6     amar    BE  65.34
# 7    amita    BE  68.33
# 8     amol    TE  56.75
# 9    anmol    BE  78.66

# %%
df['name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df[['name','marks']]
# Out:
#       name  marks
# 0     anil  56.77
# 1     amit  59.77
# 2   aniket  76.88
# 3  ajinkya  69.66
# 4     asha  63.28
# 5   ayesha  49.55
# 6     amar  65.34
# 7    amita  68.33
# 8     amol  56.75
# 9    anmol  78.66

# %%
df.name
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.drop('class', axis = 1)
# Out:
#    roll     name  marks  age
# 0     1     anil  56.77   22
# 1     2     amit  59.77   21
# 2     3   aniket  76.88   19
# 3     4  ajinkya  69.66   20
# 4     5     asha  63.28   20
# 5     6   ayesha  49.55   20
# 6     7     amar  65.34   19
# 7     8    amita  68.33   23
# 8     9     amol  56.75   20
# 9    10    anmol  78.66   21

# %%
df.drop(['class','age'], axis = 1)
# Out:
#    roll     name  marks
# 0     1     anil  56.77
# 1     2     amit  59.77
# 2     3   aniket  76.88
# 3     4  ajinkya  69.66
# 4     5     asha  63.28
# 5     6   ayesha  49.55
# 6     7     amar  65.34
# 7     8    amita  68.33
# 8     9     amol  56.75
# 9    10    anmol  78.66

# %% [markdown]
# ##### Functions

# %%
df['marks'].sum()
# Out:
# 644.9899999999999

# %%
df['marks'].min()
# Out:
# 49.55

# %%
df['marks'].max()
# Out:
# 78.66

# %%
df['marks'].mean()
# Out:
# 64.499

# %%
df['marks'].std()
# Out:
# 9.207178901994535

# %%
df['marks'].median()
# Out:
# 64.31

# %%
df.sum()
# Out:
# roll                                                    55
# name     anilamitaniketajinkyaashaayeshaamaramitaamolanmol
# class                                 TETEBETETEBEBEBETEBE
# marks                                               644.99
# age                                                    205
# dtype: object

# %%
df.mean(numeric_only=True)
# Out:
# roll      5.500
# marks    64.499
# age      20.500
# dtype: float64

# %%
df.max()
# Out:
# roll         10
# name     ayesha
# class        TE
# marks     78.66
# age          23
# dtype: object

# %%
df.sum()
# Out:
# roll                                                    55
# name     anilamitaniketajinkyaashaayeshaamaramitaamolanmol
# class                                 TETEBETETEBEBEBETEBE
# marks                                               644.99
# age                                                    205
# dtype: object

# %%
df.sum(axis=1, numeric_only=True)
# Out:
# 0     79.77
# 1     82.77
# 2     98.88
# 3     93.66
# 4     88.28
# 5     75.55
# 6     91.34
# 7     99.33
# 8     85.75
# 9    109.66
# dtype: float64

# %%
df.sum(axis=1, numeric_only=True).mean()
# Out:
# 90.499

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    10 non-null     int64
#  1   name    10 non-null     object
#  2   class   10 non-null     object
#  3   marks   10 non-null     float64
#  4   age     10 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 528.0+ bytes

# %%
df.describe()
# Out:
#            roll      marks        age
# count  10.00000  10.000000  10.000000
# mean    5.50000  64.499000  20.500000
# std     3.02765   9.207179   1.269296
# min     1.00000  49.550000  19.000000
# 25%     3.25000  57.520000  20.000000
# 50%     5.50000  64.310000  20.000000
# 75%     7.75000  69.327500  21.000000
# max    10.00000  78.660000  23.000000

# %% [markdown]
# ##### Custom Column Operations

# %%
df['roll'] + 100
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# 5    106
# 6    107
# 7    108
# 8    109
# 9    110
# Name: roll, dtype: int64

# %%
df['marks'] > 60
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: marks, dtype: bool

# %%
df['marks'] = df['marks'] / 10 + 0.47

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  6.147   22
# 1     2     amit    TE  6.447   21
# 2     3   aniket    BE  8.158   19
# 3     4  ajinkya    TE  7.436   20
# 4     5     asha    TE  6.798   20
# 5     6   ayesha    BE  5.425   20
# 6     7     amar    BE  7.004   19
# 7     8    amita    BE  7.303   23
# 8     9     amol    TE  6.145   20
# 9    10    anmol    BE  8.336   21

# %%
df['cgpa'] = df['marks'] / 10 + 0.47

# %%
df
# Out:
#    roll     name class  marks  age    cgpa
# 0     1     anil    TE  6.147   22  1.0847
# 1     2     amit    TE  6.447   21  1.1147
# 2     3   aniket    BE  8.158   19  1.2858
# 3     4  ajinkya    TE  7.436   20  1.2136
# 4     5     asha    TE  6.798   20  1.1498
# 5     6   ayesha    BE  5.425   20  1.0125
# 6     7     amar    BE  7.004   19  1.1704
# 7     8    amita    BE  7.303   23  1.2003
# 8     9     amol    TE  6.145   20  1.0845
# 9    10    anmol    BE  8.336   21  1.3036

# %%
y = ['M','M','M','M','F','F','M','F','M','M']

# %%
len(y)
# Out:
# 10

# %%
df['gender'] = y
df
# Out:
#    roll     name class  marks  age    cgpa gender
# 0     1     anil    TE  6.147   22  1.0847      M
# 1     2     amit    TE  6.447   21  1.1147      M
# 2     3   aniket    BE  8.158   19  1.2858      M
# 3     4  ajinkya    TE  7.436   20  1.2136      M
# 4     5     asha    TE  6.798   20  1.1498      F
# 5     6   ayesha    BE  5.425   20  1.0125      F
# 6     7     amar    BE  7.004   19  1.1704      M
# 7     8    amita    BE  7.303   23  1.2003      F
# 8     9     amol    TE  6.145   20  1.0845      M
# 9    10    anmol    BE  8.336   21  1.3036      M

# %%
df = pd.read_csv('datasets/student.csv')

# %%
newdf = pd.DataFrame({
    'roll':range(1,11),
    'cgpa': df['marks'] / 10 + 0.47,
    'gender': ['M','M','M','M','F','F','M','F','M','M']
})

# %%
newdf
# Out:
#    roll   cgpa gender
# 0     1  6.147      M
# 1     2  6.447      M
# 2     3  8.158      M
# 3     4  7.436      M
# 4     5  6.798      F
# 5     6  5.425      F
# 6     7  7.004      M
# 7     8  7.303      F
# 8     9  6.145      M
# 9    10  8.336      M

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
newdf.columns
# Out:
# Index(['roll', 'cgpa', 'gender'], dtype='object')

# %%
df.merge(newdf, on='roll')
# Out:
#    roll     name class  marks  age   cgpa gender
# 0     1     anil    TE  56.77   22  6.147      M
# 1     2     amit    TE  59.77   21  6.447      M
# 2     3   aniket    BE  76.88   19  8.158      M
# 3     4  ajinkya    TE  69.66   20  7.436      M
# 4     5     asha    TE  63.28   20  6.798      F
# 5     6   ayesha    BE  49.55   20  5.425      F
# 6     7     amar    BE  65.34   19  7.004      M
# 7     8    amita    BE  68.33   23  7.303      F
# 8     9     amol    TE  56.75   20  6.145      M
# 9    10    anmol    BE  78.66   21  8.336      M

# %%
df5 = pd.read_csv('datasets/student5.csv')

# %%
df5
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
cdf = pd.concat([df, df5])

# %%
cdf
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
cdf = pd.concat([df, df5], ignore_index=True)

# %%
cdf
# Out:
#     roll     name class  marks  age
# 0      1     anil    TE  56.77   22
# 1      2     amit    TE  59.77   21
# 2      3   aniket    BE  76.88   19
# 3      4  ajinkya    TE  69.66   20
# 4      5     asha    TE  63.28   20
# 5      6   ayesha    BE  49.55   20
# 6      7     amar    BE  65.34   19
# 7      8    amita    BE  68.33   23
# 8      9     amol    TE  56.75   20
# 9     10    anmol    BE  78.66   21
# 10     1   surbhi    TE  67.44   23
# 11     2    sujay    TE  74.12   22
# 12     3  subhash    BE  82.44   21
# 13     4   sachin    TE  59.33   21
# 14     5  shalini    TE  63.45   20

# %% [markdown]
# ##### String Operations

# %%
name = 'Pune'

# %%
name.upper()
# Out:
# 'PUNE'

# %%
name.replace('u','oo')
# Out:
# 'Poone'

# %%
name.istitle()
# Out:
# True

# %%
df['name'].str.upper()
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5     AYESHA
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df['name'].str.startswith('an')
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9     True
# Name: name, dtype: bool

# %%
df['name'].str.replace('i','ee')
# Out:
# 0       aneel
# 1       ameet
# 2     aneeket
# 3    ajeenkya
# 4        asha
# 5      ayesha
# 6        amar
# 7      ameeta
# 8        amol
# 9       anmol
# Name: name, dtype: object

# %%
df['name'].str.title()
# Out:
# 0       Anil
# 1       Amit
# 2     Aniket
# 3    Ajinkya
# 4       Asha
# 5     Ayesha
# 6       Amar
# 7      Amita
# 8       Amol
# 9      Anmol
# Name: name, dtype: object

# %%
df['name'].str.len()
# Out:
# 0    4
# 1    4
# 2    6
# 3    7
# 4    4
# 5    6
# 6    4
# 7    5
# 8    4
# 9    5
# Name: name, dtype: int64

# %%
df['name'].str.repeat(3)
# Out:
# 0             anilanilanil
# 1             amitamitamit
# 2       aniketaniketaniket
# 3    ajinkyaajinkyaajinkya
# 4             ashaashaasha
# 5       ayeshaayeshaayesha
# 6             amaramaramar
# 7          amitaamitaamita
# 8             amolamolamol
# 9          anmolanmolanmol
# Name: name, dtype: object

# %% [markdown]
# ##### Aggregate Operations

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df['class'].value_counts()
# Out:
# class
# TE    5
# BE    5
# Name: count, dtype: int64

# %%
df['age'].value_counts()
# Out:
# age
# 20    4
# 21    2
# 19    2
# 22    1
# 23    1
# Name: count, dtype: int64

# %%
gr = df.groupby('class')

# %%
gr.groups
# Out:
# {'BE': [2, 5, 6, 7, 9], 'TE': [0, 1, 3, 4, 8]}

# %%
gr.get_group('TE')
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 8     9     amol    TE  56.75   20

# %%
gr['marks'].min()
# Out:
# class
# BE    49.55
# TE    56.75
# Name: marks, dtype: float64

# %%
gr['marks'].mean()
# Out:
# class
# BE    67.752
# TE    61.246
# Name: marks, dtype: float64

# %%
gr.max()
# Out:
#        roll    name  marks  age
# class
# BE       10  ayesha  78.66   23
# TE        9    asha  69.66   22

# %%
gr.describe()
# Out:
#        roll                                          marks          ...  \
#       count mean       std  min  25%  50%  75%   max count    mean  ...
# class                                                               ...
# BE      5.0  6.8  2.588436  3.0  6.0  7.0  8.0  10.0   5.0  67.752  ...
# TE      5.0  4.2  3.114482  1.0  2.0  4.0  5.0   9.0   5.0  61.246  ...
#
#                       age
#          75%    max count  mean       std   min   25%   50%   75%   max
# class
# BE     76.88  78.66   5.0  20.4  1.673320  19.0  19.0  20.0  21.0  23.0
# TE     63.28  69.66   5.0  20.6  0.894427  20.0  20.0  20.0  21.0  22.0
#
# [2 rows x 24 columns]

# %%
df.max()
# Out:
# roll         10
# name     ayesha
# class        TE
# marks     78.66
# age          23
# dtype: object

# %%
df.dtypes
# Out:
# roll       int64
# name      object
# class     object
# marks    float64
# age        int64
# dtype: object

# %%
type(gr)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
gr.head()
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %% [markdown]
# ##### Boolean Filtering

# %%
mask = df['marks'] > 60

# %%
mask
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: marks, dtype: bool

# %%
df[mask]
# Out:
#    roll     name class  marks  age
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21

# %%
df[df['marks'] > 60]
# Out:
#    roll     name class  marks  age
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21

# %%
x = df[(df['marks'] > 60) & (df['class'] == 'BE')]

# %%
x
# Out:
#    roll    name class  marks  age
# 2     3  aniket    BE  76.88   19
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 9    10   anmol    BE  78.66   21

# %% [markdown]
# ##### Sorting

# %%
df.sort_values('class')
# Out:
#    roll     name class  marks  age
# 2     3   aniket    BE  76.88   19
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 8     9     amol    TE  56.75   20

# %%
df.sort_values(['class','age','marks'])
# Out:
#    roll     name class  marks  age
# 6     7     amar    BE  65.34   19
# 2     3   aniket    BE  76.88   19
# 5     6   ayesha    BE  49.55   20
# 9    10    anmol    BE  78.66   21
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 4     5     asha    TE  63.28   20
# 3     4  ajinkya    TE  69.66   20
# 1     2     amit    TE  59.77   21
# 0     1     anil    TE  56.77   22

# %%
df.sort_values('marks', ascending=False)
# Out:
#    roll     name class  marks  age
# 9    10    anmol    BE  78.66   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 7     8    amita    BE  68.33   23
# 6     7     amar    BE  65.34   19
# 4     5     asha    TE  63.28   20
# 1     2     amit    TE  59.77   21
# 0     1     anil    TE  56.77   22
# 8     9     amol    TE  56.75   20
# 5     6   ayesha    BE  49.55   20

# %% [markdown]
# ##### Export / Save the data

# %%
x = df[(df['marks'] > 60) & (df['class'] == 'BE')]
x['name'] = x['name'].str.title()
# Out:
# /tmp/ipykernel_68893/2205680812.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['name'] = x['name'].str.title()

# %%
x
# Out:
#    roll    name class  marks  age
# 2     3  Aniket    BE  76.88   19
# 6     7    Amar    BE  65.34   19
# 7     8   Amita    BE  68.33   23
# 9    10   Anmol    BE  78.66   21

# %%
x.to_csv('output.csv', index=False)

# %%
x.to_html('output.html', index=False)
